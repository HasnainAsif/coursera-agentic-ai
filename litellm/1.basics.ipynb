# %%
from litellm import completion
from typing import List, Dict

from dotenv import load_dotenv
load_dotenv(override=True)
# Out:
# True

# %%
def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o-mini",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content


messages = [
    {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
    {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."}
]

response = generate_response(messages)
print(response)
# Out:
# Here’s a simple function in Python that swaps the keys and values in a dictionary. This implementation assumes that the values in the original dictionary are unique and can be used as keys in the new dictionary.
#
# ```python
# def swap_dict(d):
#     """Swap keys and values in a dictionary."""
#     return {value: key for key, value in d.items()}
#
# # Example usage:
# original_dict = {'a': 1, 'b': 2, 'c': 3}
# swapped_dict = swap_dict(original_dict)
# print(swapped_dict)  # Output: {1: 'a', 2: 'b', 3: 'c'}
# ```
#
# In this function:
# - We use a dictionary comprehension to iterate over the items of the original dictionary.
# - For each key-value pair, we create a new key-value pair in the new dictionary, where the original value becomes the new key, and the original key becomes the new value.
#
# You can call this function with any dictionary that meets the criteria mentioned above. If the values are not unique, the last key-value pair encountered with the same value will overwrite the previous ones in the new dictionary.
