# %% [markdown]
# # Convert text-to-speech using gtts
#
# gtts --> Google Text to Speech

# %%
# %pip install gTTS==2.5.4 | tail -n 1
# %pip install openai==1.30.1 | tail -n 1
# Out:
# Successfully installed click-8.1.8 gTTS-2.5.4
# Note: you may need to restart the kernel to use updated packages.

# %%
from openai import OpenAI

client = OpenAI()

# Function to generate an educational story
def generate_story(topic):
    prompt = f"""Write are an expert in writing an engaging and educational story for beginners. 
            Use simple and clear language to explain basic concepts. 
            Include interesting facts and keep it friendly and encouraging. 
            The story must be around 150-200 words and end with a short summary of what we learned. 
            Make it perfect for someone just starting to learn about this topic."""
    
    # Generate text using the model with our carefully crafted prompt
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": prompt},
            {"role": "user", "content": f"Create an interactive story for this topic: {topic}"}
        ],
        max_tokens=1000,
    )
    return response

# %%
topic = "the life cycle of trees"
story = generate_story(topic)
print("Generated Story:\n", story)
# Out:
# Generated Story:
#  ChatCompletion(id='chatcmpl-D53sSlJqNJkk4gyDP9IlqOOuxcca6', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='Once upon a time in a sunny forest, there was a tiny seed named Sammy. Sammy dreamed of growing into a tall tree. One day, the gentle rain fell, and the warm sun shone brightly. Sammy felt cozy and decided it was time to grow! \n\nWith a little sprout, he pushed through the soil, feeling the warm sunlight. "Look at me!" Sammy cheered. This stage is called germination. As days passed, Sammy\'s roots grew deeper into the ground while his tiny leaves reached higher to drink the sunlight.\n\nAs seasons changed, Sammy faced challenges. Strong winds and snow made him shiver. But with every storm, he grew stronger. After a few years, he became a sapling. With more sunshine and rain, he turned into a mighty tree, standing tall with a thick trunk and branches full of green leaves.\n\nIn autumn, Sammy’s leaves changed color and fell to the ground. "These leaves will become new soil!" he realized. And so, with time, new seeds would form, starting the cycle again.\n\n**Summary:** Trees start as seeds, grow through stages like germination, and become strong trees. They face challenges and help the earth by recycling nutrients when leaves fall. Nature’s cycle continues as new seeds sprout from the old. Keep watching the trees around you – they tell a wonderful story!', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1770098916, model='gpt-4o-mini-2024-07-18', object='chat.completion', service_tier='default', system_fingerprint='fp_1590f93f9d', usage=CompletionUsage(completion_tokens=274, prompt_tokens=100, total_tokens=374, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=0, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %%
story_text = story.choices[0].message.content
story_text
# Out:
# 'Once upon a time in a sunny forest, there was a tiny seed named Sammy. Sammy dreamed of growing into a tall tree. One day, the gentle rain fell, and the warm sun shone brightly. Sammy felt cozy and decided it was time to grow! \n\nWith a little sprout, he pushed through the soil, feeling the warm sunlight. "Look at me!" Sammy cheered. This stage is called germination. As days passed, Sammy\'s roots grew deeper into the ground while his tiny leaves reached higher to drink the sunlight.\n\nAs seasons changed, Sammy faced challenges. Strong winds and snow made him shiver. But with every storm, he grew stronger. After a few years, he became a sapling. With more sunshine and rain, he turned into a mighty tree, standing tall with a thick trunk and branches full of green leaves.\n\nIn autumn, Sammy’s leaves changed color and fell to the ground. "These leaves will become new soil!" he realized. And so, with time, new seeds would form, starting the cycle again.\n\n**Summary:** Trees start as seeds, grow through stages like germination, and become strong trees. They face challenges and help the earth by recycling nutrients when leaves fall. Nature’s cycle continues as new seeds sprout from the old. Keep watching the trees around you – they tell a wonderful story!'

# %% [markdown]
# ## Convert the story to speech

# %%
from gtts import gTTS
from IPython.display import Audio
import io

# Initialize text-to-speech with the generated story
tts = gTTS(story_text)

# Save the audio to a bytes buffer in memory
audio_bytes = io.BytesIO()
tts.write_to_fp(audio_bytes)
audio_bytes.seek(0)

# Create and display an audio player widget in the notebook
Audio(audio_bytes.read(), autoplay=False)

# %%
# Save as MP3 file
tts.save("./generated_story.mp3")
